# %%
import numpy as np 
from matplotlib import pyplot as plt

# %%
updated_labels = np.load("../R_2000_updated_labels.npy")

# %%
plt.imshow(updated_labels)

# %%
np.unique(updated_labels)
# Out:
# array([-1,  0,  1])

# %%
updated_labels[100][500]
# Out:
# 0
